# %%
import sys

sys.path.insert(0, ".")
sys.path.append("../")  # import py files from parent folders/..*

# %% [markdown]
# ## SMA

# %%
import pandas as pd
import yfinance as yf
import cufflinks as cf
import plotly.offline

cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

# Define the Ticker Symbol
ticker_symbol = "GOOG"

# Get the data on this ticker
ticker_data = yf.Ticker(ticker_symbol)

# Get the historical prices for the specified period
ticker_df = ticker_data.history(period="1d", start="2021-1-1", end="2023-6-15")

# Calculate Simple Moving Averages
ticker_df["SMA30"] = ticker_df["Close"].rolling(window=30).mean()
ticker_df["SMA100"] = ticker_df["Close"].rolling(window=100).mean()

# Define the data
data = [ticker_df["SMA30"], ticker_df["SMA100"], ticker_df["Close"]]

# Plot the chart
ticker_df.iplot(
    title="Moving Averages of " + ticker_symbol,
    xTitle="Date",
    yTitle="Price",
    theme="pearl",
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="5908201e-0e3a-4c4a-8849-e39ea6d183e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("5908201e-0e3a-4c4a-8849-e39ea6d183e7")) {                    Plotly.newPlot(                        "5908201e-0e3a-4c4a-8849-e39ea6d183e7",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Open","text":"","x":["2021-01-04 00:00:00-05:00","2021-01-05 00:00:00-05:00","2021-01-06 00:00:00-05:00","2021-01-07 00:00:00-05:00","2021-01-08 00:00:00-05:00","2021-01-11 00:00:00-05:00","2021-01-12 00:00:00-05:00","2021-01-13 00:00:00-05:00","2021-01-14 00:00:00-05:00","2021-01-15 00:00:00-05:00","2021-01-19 00:00:00-05:00","2021-01-20 00:00:00-05:00","2021-01-21 00:00:00-05:00","2021-01-22 00:00:00-05:00","2021-01-25 00:00:00-05:00","2021-01-26 00:00:00-05:00","2021-01-27 00:00:00-05:00","2021-01-28 00:00:00-05:00","2021-01-29 00:00:00-05:00","2021-02-01 00:00:00-05:00","2021-02-02 00:00:00-05:00","2021-02-03 00:00:00-05:00","2021-02-04 00:00:00-05:00","2021-02-05 00:00:00-05:00","2021-02-08 00:00:00-05:00","2021-02-09 00:00:00-05:00","2021-02-10 00:00:00-05:00","2021-02-11 00:00:00-05:00","2021-02-12 00:00:00-05:00","2021-02-16 00:00:00-05:00","2021-02-17 00:00:00-05:00","2021-02-18 00:00:00-05:00","2021-02-19 00:00:00-05:00","2021-02-22 00:00:00-05:00","2021-02-23 00:00:00-05:00","2021-02-24 00:00:00-05:00","2021-02-25 00:00:00-05:00","2021-02-26 00:00:00-05:00","2021-03-01 00:00:00-05:00","2021-03-02 00:00:00-05:00","2021-03-03 00:00:00-05:00","2021-03-04 00:00:00-05:00","2021-03-05 00:00:00-05:00","2021-03-08 00:00:00-05:00","2021-03-09 00:00:00-05:00","2021-03-10 00:00:00-05:00","2021-03-11 00:00:00-